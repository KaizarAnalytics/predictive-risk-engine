# %%
import sys
sys.path.append('..')

from pathlib import Path
import pandas as pd

from src.data.preprocess import load_raw
from src.data.feature_engineering import apply_feature_engineering

PROJECT_ROOT = Path.cwd().resolve().parents[0]
DATA_DIR = PROJECT_ROOT / "data"

# %%
df_raw, DATA_DIR = load_raw()
df_fe = apply_feature_engineering(df_raw)

df_fe.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... PaperlessBilling  \
# 0  No phone service             DSL             No  ...              Yes
# 1                No             DSL            Yes  ...               No
# 2                No             DSL            Yes  ...              Yes
# 3  No phone service             DSL            Yes  ...               No
# 4                No     Fiber optic             No  ...              Yes
#
# ...

# %%
import yaml

feature_meta = {
    "tenure_bucket": "Categorized tenure in 5 risk groups",
    "is_month_to_month": "Binary flag for contract risk",
    "has_fiber": "Fiber-optic internet flag",
    "avg_monthly_total": "TotalCharges / tenure"
}

yaml.safe_dump(feature_meta, open("../src/config/feature_metadata.yaml", "w"))

# %%
processed_path = DATA_DIR / "processed" / "telco_churn_fe.csv"
processed_path.parent.mkdir(parents=True, exist_ok=True)
df_fe.to_csv(processed_path, index=False)

# %%
import yaml

feature_meta = {
    "tenure_bucket": "Categorized tenure in 5 risk groups",
    "is_month_to_month": "Binary flag for contract risk",
    "has_fiber": "Fiber-optic internet flag",
    "avg_monthly_total": "TotalCharges / tenure"
}

yaml.safe_dump(feature_meta, open("../src/config/feature_metadata.yaml", "w"))
